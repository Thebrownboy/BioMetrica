# %% [markdown]
# # بسم الله الرحمن الرحيم

# %%
from utils import *
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
# Out:
# 2023-05-13 11:09:01.048571: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-13 11:09:01.311673: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-13 11:09:01.311697: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-05-13 11:09:02.516797: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-05-13 11:09:02.519832: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-05-13 11:09:02.519852: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/thebrownboy/anaconda3/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
df = pd.read_csv("dataset/body_level_classification_train.csv")
df_original= cleaning_data(df).copy()
all_class_train,all_class_test=data_spliting(df_original,1/3)
## shuffling 
all_class_train = all_class_train.sample(frac=1.0, random_state=42)
all_class_test = all_class_test.sample(frac=1.0, random_state=42)
X_train=all_class_train.drop(["Body_Level"],axis=1).to_numpy()
Y_train=all_class_train["Body_Level"].to_numpy()
X_test =all_class_test.drop(["Body_Level"],axis=1).to_numpy()
Y_test =all_class_test["Body_Level"].to_numpy()
X_train, scaler= data_scaling(X_train)
X_val, X_test, Y_val, Y_test = train_test_split(X_test
                                                     , Y_test, test_size=0.5, random_state=42)
X_val = scaler.transform(X_val)
X_test=scaler.transform(X_test)

# %%
# Generate a toy dataset
total_samples = 986  # total number of samples
class_0 = 127  # number of samples in class 0
class_1 = 134  # number of samples in class 1
class_2 = 271  # number of samples in class 2
class_3 = 454  # number of samples in class 3

class_weights = {
    0: total_samples / (4 * class_0),
    1: total_samples / (4 * class_1),
    2: total_samples / (4 * class_2),
    3: total_samples / (4 * class_3)
}



# Define the random forest model
model = RandomForestClassifier(random_state=42,class_weight=class_weights)

# Define the parameter grid to search over
param_grid = {
    'n_estimators': [50, 100, 200,300,400,500,600],
    'max_depth': [10, 20, 30, None],
}

# Define the grid search object
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=None,verbose=2)

# Fit the grid search object to the data
grid_search.fit(X_train, Y_train)

# Print the best parameters and best score
print("Best parameters: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# [CV] END ......................max_depth=10, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=10, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=10, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=10, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=10, n_estimators=50; total time=   0.1s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=10, n_estimators=200; total time=   0.4s
# [CV] END .....................max_depth=10, n_estimators=200; total time=   0.3s
# [CV] END .....................max_depth=10, n_estimators=200; total time=   0.3s
# [CV] END .....................max_depth=10, n_estimators=200; total time=   0.3s
# [CV] END .....................max_depth=10, n_estimators=200; total time=   0.3s
# [CV] END .....................max_depth=10, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=10, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=10, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=10, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=10, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=10, n_estimators=400; total time=   0.6s
# [CV] END .....................max_depth=10, n_estimators=400; total time=   0.7s
# [CV] END .....................max_depth=10, n_estimators=400; total time=   0.6s
# [CV] END .....................max_depth=10, n_estimators=400; total time=   0.6s
# [CV] END .....................max_depth=10, n_estimators=400; total time=   0.6s
# [CV] END .....................max_depth=10, n_estimators=500; total time=   0.9s
# [CV] END .....................max_depth=10, n_estimators=500; total time=   0.7s
# [CV] END .....................max_depth=10, n_estimators=500; total time=   0.8s
# [CV] END .....................max_depth=10, n_estimators=500; total time=   0.9s
# [CV] END .....................max_depth=10, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=10, n_estimators=600; total time=   1.0s
# [CV] END .....................max_depth=10, n_estimators=600; total time=   0.9s
# [CV] END .....................max_depth=10, n_estimators=600; total time=   1.0s
# [CV] END .....................max_depth=10, n_estimators=600; total time=   0.9s
# [CV] END .....................max_depth=10, n_estimators=600; total time=   0.9s
# [CV] END ......................max_depth=20, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=20, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=20, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=20, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=20, n_estimators=50; total time=   0.1s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=20, n_estimators=200; total time=   0.3s
# [CV] END .....................max_depth=20, n_estimators=200; total time=   0.3s
# [CV] END .....................max_depth=20, n_estimators=200; total time=   0.3s
# [CV] END .....................max_depth=20, n_estimators=200; total time=   0.3s
# [CV] END .....................max_depth=20, n_estimators=200; total time=   0.3s
# [CV] END .....................max_depth=20, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=20, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=20, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=20, n_estimators=300; total time=   0.6s
# [CV] END .....................max_depth=20, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=20, n_estimators=400; total time=   0.6s
# [CV] END .....................max_depth=20, n_estimators=400; total time=   0.6s
# [CV] END .....................max_depth=20, n_estimators=400; total time=   0.6s
# [CV] END .....................max_depth=20, n_estimators=400; total time=   0.6s
# [CV] END .....................max_depth=20, n_estimators=400; total time=   0.6s
# [CV] END .....................max_depth=20, n_estimators=500; total time=   0.8s
# [CV] END .....................max_depth=20, n_estimators=500; total time=   0.9s
# [CV] END .....................max_depth=20, n_estimators=500; total time=   0.8s
# [CV] END .....................max_depth=20, n_estimators=500; total time=   0.9s
# [CV] END .....................max_depth=20, n_estimators=500; total time=   0.9s
# [CV] END .....................max_depth=20, n_estimators=600; total time=   1.0s
# [CV] END .....................max_depth=20, n_estimators=600; total time=   1.0s
# [CV] END .....................max_depth=20, n_estimators=600; total time=   1.0s
# [CV] END .....................max_depth=20, n_estimators=600; total time=   0.9s
# [CV] END .....................max_depth=20, n_estimators=600; total time=   1.0s
# [CV] END ......................max_depth=30, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=30, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=30, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=30, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=30, n_estimators=50; total time=   0.1s
# [CV] END .....................max_depth=30, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=30, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=30, n_estimators=100; total time=   0.1s
# [CV] END .....................max_depth=30, n_estimators=100; total time=   0.1s
# [CV] END .....................max_depth=30, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=30, n_estimators=200; total time=   0.3s
# [CV] END .....................max_depth=30, n_estimators=200; total time=   0.3s
# [CV] END .....................max_depth=30, n_estimators=200; total time=   0.3s
# [CV] END .....................max_depth=30, n_estimators=200; total time=   0.3s
# [CV] END .....................max_depth=30, n_estimators=200; total time=   0.4s
# [CV] END .....................max_depth=30, n_estimators=300; total time=   0.7s
# [CV] END .....................max_depth=30, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=30, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=30, n_estimators=300; total time=   0.4s
# [CV] END .....................max_depth=30, n_estimators=300; total time=   0.5s
# [CV] END .....................max_depth=30, n_estimators=400; total time=   0.6s
# [CV] END .....................max_depth=30, n_estimators=400; total time=   0.7s
# [CV] END .....................max_depth=30, n_estimators=400; total time=   0.6s
# [CV] END .....................max_depth=30, n_estimators=400; total time=   0.7s
# [CV] END .....................max_depth=30, n_estimators=400; total time=   0.7s
# [CV] END .....................max_depth=30, n_estimators=500; total time=   0.8s
# [CV] END .....................max_depth=30, n_estimators=500; total time=   0.8s
# [CV] END .....................max_depth=30, n_estimators=500; total time=   0.8s
# [CV] END .....................max_depth=30, n_estimators=500; total time=   0.9s
# [CV] END .....................max_depth=30, n_estimators=500; total time=   0.9s
# [CV] END .....................max_depth=30, n_estimators=600; total time=   1.1s
# [CV] END .....................max_depth=30, n_estimators=600; total time=   1.0s
# [CV] END .....................max_depth=30, n_estimators=600; total time=   1.0s
# [CV] END .....................max_depth=30, n_estimators=600; total time=   0.9s
# [CV] END .....................max_depth=30, n_estimators=600; total time=   1.0s
# [CV] END ....................max_depth=None, n_estimators=50; total time=   0.1s
# [CV] END ....................max_depth=None, n_estimators=50; total time=   0.1s
# [CV] END ....................max_depth=None, n_estimators=50; total time=   0.1s
# [CV] END ....................max_depth=None, n_estimators=50; total time=   0.1s
# [CV] END ....................max_depth=None, n_estimators=50; total time=   0.1s
# [CV] END ...................max_depth=None, n_estimators=100; total time=   0.2s
# [CV] END ...................max_depth=None, n_estimators=100; total time=   0.2s
# [CV] END ...................max_depth=None, n_estimators=100; total time=   0.2s
# [CV] END ...................max_depth=None, n_estimators=100; total time=   0.2s
# [CV] END ...................max_depth=None, n_estimators=100; total time=   0.2s
# [CV] END ...................max_depth=None, n_estimators=200; total time=   0.4s
# [CV] END ...................max_depth=None, n_estimators=200; total time=   0.3s
# [CV] END ...................max_depth=None, n_estimators=200; total time=   0.3s
# [CV] END ...................max_depth=None, n_estimators=200; total time=   0.3s
# [CV] END ...................max_depth=None, n_estimators=200; total time=   0.3s
# [CV] END ...................max_depth=None, n_estimators=300; total time=   0.5s
# [CV] END ...................max_depth=None, n_estimators=300; total time=   0.6s
# [CV] END ...................max_depth=None, n_estimators=300; total time=   0.5s
# [CV] END ...................max_depth=None, n_estimators=300; total time=   0.5s
# [CV] END ...................max_depth=None, n_estimators=300; total time=   0.5s
# [CV] END ...................max_depth=None, n_estimators=400; total time=   0.7s
# [CV] END ...................max_depth=None, n_estimators=400; total time=   0.7s
# [CV] END ...................max_depth=None, n_estimators=400; total time=   0.7s
# [CV] END ...................max_depth=None, n_estimators=400; total time=   0.7s
# [CV] END ...................max_depth=None, n_estimators=400; total time=   0.6s
# [CV] END ...................max_depth=None, n_estimators=500; total time=   0.8s
# [CV] END ...................max_depth=None, n_estimators=500; total time=   0.9s
# [CV] END ...................max_depth=None, n_estimators=500; total time=   0.8s
# [CV] END ...................max_depth=None, n_estimators=500; total time=   0.9s
# [CV] END ...................max_depth=None, n_estimators=500; total time=   0.8s
# [CV] END ...................max_depth=None, n_estimators=600; total time=   1.1s
# [CV] END ...................max_depth=None, n_estimators=600; total time=   1.0s
# [CV] END ...................max_depth=None, n_estimators=600; total time=   1.1s
# [CV] END ...................max_depth=None, n_estimators=600; total time=   1.1s
# [CV] END ...................max_depth=None, n_estimators=600; total time=   1.1s
# Best parameters:  {'max_depth': 20, 'n_estimators': 200}
# Best score:  0.9401527970055887

# %%
cv_results = grid_search.cv_results_

for mean_score, params in zip(cv_results['mean_test_score'], cv_results['params']):
    print(params, mean_score)
# Out:
# {'max_depth': 10, 'n_estimators': 50} 0.9259652361175205
# {'max_depth': 10, 'n_estimators': 100} 0.9290109213967082
# {'max_depth': 10, 'n_estimators': 200} 0.9259652361175205
# {'max_depth': 10, 'n_estimators': 300} 0.9310413782495001
# {'max_depth': 10, 'n_estimators': 400} 0.9340768086960981
# {'max_depth': 10, 'n_estimators': 500} 0.9300261498231042
# {'max_depth': 10, 'n_estimators': 600} 0.9310259960006153
# {'max_depth': 20, 'n_estimators': 50} 0.9289904117315286
# {'max_depth': 20, 'n_estimators': 100} 0.938122340152797
# {'max_depth': 20, 'n_estimators': 200} 0.9401527970055887
# {'max_depth': 20, 'n_estimators': 300} 0.938122340152797
# {'max_depth': 20, 'n_estimators': 400} 0.939137568579193
# {'max_depth': 20, 'n_estimators': 500} 0.9401476695892941
# {'max_depth': 20, 'n_estimators': 600} 0.9401476695892941
# {'max_depth': 30, 'n_estimators': 50} 0.9289904117315286
# {'max_depth': 30, 'n_estimators': 100} 0.938122340152797
# {'max_depth': 30, 'n_estimators': 200} 0.9401527970055887
# {'max_depth': 30, 'n_estimators': 300} 0.938122340152797
# {'max_depth': 30, 'n_estimators': 400} 0.939137568579193
# {'max_depth': 30, 'n_estimators': 500} 0.9401476695892941
# {'max_depth': 30, 'n_estimators': 600} 0.9401476695892941
# {'max_depth': None, 'n_estimators': 50} 0.9289904117315286
# {'max_depth': None, 'n_estimators': 100} 0.938122340152797
# {'max_depth': None, 'n_estimators': 200} 0.9401527970055887
# {'max_depth': None, 'n_estimators': 300} 0.938122340152797
# {'max_depth': None, 'n_estimators': 400} 0.939137568579193
# {'max_depth': None, 'n_estimators': 500} 0.9401476695892941
# {'max_depth': None, 'n_estimators': 600} 0.9401476695892941

# %%
np.sum(grid_search.best_estimator_.predict(X_val) == Y_val) / Y_val.shape[0]
# Out:
# 0.8979591836734694

# %%
np.sum(grid_search.best_estimator_.predict(X_test) == Y_test) / Y_test.shape[0]
# Out:
# 0.8414634146341463

# %%
oversampled= over_sampling(all_class_train,sampling_ratio=0.5)
X_train=oversampled.drop(["Body_Level"],axis=1).to_numpy()
Y_train=oversampled["Body_Level"].to_numpy()
X_test =all_class_test.drop(["Body_Level"],axis=1).to_numpy()
Y_test =all_class_test["Body_Level"].to_numpy()
X_train, scaler= data_scaling(X_train)
X_val, X_test, Y_val, Y_test = train_test_split(X_test
                                                     , Y_test, test_size=0.5, random_state=42)
X_val = scaler.transform(X_val)
X_test=scaler.transform(X_test)

# %%
# Generate a toy dataset
total_samples = 986  # total number of samples
class_0 = 127  # number of samples in class 0
class_1 = 134  # number of samples in class 1
class_2 = 271  # number of samples in class 2
class_3 = 454  # number of samples in class 3

class_weights = {
    0: total_samples / (4 * class_0),
    1: total_samples / (4 * class_1),
    2: total_samples / (4 * class_2),
    3: total_samples / (4 * class_3)
}



# Define the random forest model
model = RandomForestClassifier(random_state=42,class_weight=class_weights)

# Define the parameter grid to search over
param_grid = {
    'n_estimators': [400,500,600,700,800],
    'max_depth': [10, 20, 30,40,50,60],
}

# Define the grid search object
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=None,verbose=2)

# Fit the grid search object to the data
grid_search.fit(X_train, Y_train)

# Print the best parameters and best score
print("Best parameters: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END .....................max_depth=10, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=10, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=10, n_estimators=400; total time=   0.7s
# [CV] END .....................max_depth=10, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=10, n_estimators=400; total time=   0.9s
# [CV] END .....................max_depth=10, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=10, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=10, n_estimators=500; total time=   0.9s
# [CV] END .....................max_depth=10, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=10, n_estimators=500; total time=   0.9s
# [CV] END .....................max_depth=10, n_estimators=600; total time=   1.1s
# [CV] END .....................max_depth=10, n_estimators=600; total time=   1.1s
# [CV] END .....................max_depth=10, n_estimators=600; total time=   1.1s
# [CV] END .....................max_depth=10, n_estimators=600; total time=   1.1s
# [CV] END .....................max_depth=10, n_estimators=600; total time=   1.1s
# [CV] END .....................max_depth=10, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=10, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=10, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=10, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=10, n_estimators=700; total time=   1.6s
# [CV] END .....................max_depth=10, n_estimators=800; total time=   1.5s
# [CV] END .....................max_depth=10, n_estimators=800; total time=   1.5s
# [CV] END .....................max_depth=10, n_estimators=800; total time=   1.5s
# [CV] END .....................max_depth=10, n_estimators=800; total time=   1.4s
# [CV] END .....................max_depth=10, n_estimators=800; total time=   1.5s
# [CV] END .....................max_depth=20, n_estimators=400; total time=   0.9s
# [CV] END .....................max_depth=20, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=20, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=20, n_estimators=400; total time=   0.9s
# [CV] END .....................max_depth=20, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=20, n_estimators=500; total time=   1.1s
# [CV] END .....................max_depth=20, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=20, n_estimators=500; total time=   1.2s
# [CV] END .....................max_depth=20, n_estimators=500; total time=   1.1s
# [CV] END .....................max_depth=20, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=20, n_estimators=600; total time=   1.1s
# [CV] END .....................max_depth=20, n_estimators=600; total time=   1.1s
# [CV] END .....................max_depth=20, n_estimators=600; total time=   1.1s
# [CV] END .....................max_depth=20, n_estimators=600; total time=   1.1s
# [CV] END .....................max_depth=20, n_estimators=600; total time=   1.1s
# [CV] END .....................max_depth=20, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=20, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=20, n_estimators=700; total time=   1.4s
# [CV] END .....................max_depth=20, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=20, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=20, n_estimators=800; total time=   1.6s
# [CV] END .....................max_depth=20, n_estimators=800; total time=   1.6s
# [CV] END .....................max_depth=20, n_estimators=800; total time=   1.5s
# [CV] END .....................max_depth=20, n_estimators=800; total time=   1.5s
# [CV] END .....................max_depth=20, n_estimators=800; total time=   1.6s
# [CV] END .....................max_depth=30, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=30, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=30, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=30, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=30, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=30, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=30, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=30, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=30, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=30, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=30, n_estimators=600; total time=   1.4s
# [CV] END .....................max_depth=30, n_estimators=600; total time=   1.2s
# [CV] END .....................max_depth=30, n_estimators=600; total time=   1.1s
# [CV] END .....................max_depth=30, n_estimators=600; total time=   1.3s
# [CV] END .....................max_depth=30, n_estimators=600; total time=   1.1s
# [CV] END .....................max_depth=30, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=30, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=30, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=30, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=30, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=30, n_estimators=800; total time=   1.6s
# [CV] END .....................max_depth=30, n_estimators=800; total time=   1.4s
# [CV] END .....................max_depth=30, n_estimators=800; total time=   1.5s
# [CV] END .....................max_depth=30, n_estimators=800; total time=   1.4s
# [CV] END .....................max_depth=30, n_estimators=800; total time=   1.4s
# [CV] END .....................max_depth=40, n_estimators=400; total time=   0.7s
# [CV] END .....................max_depth=40, n_estimators=400; total time=   0.7s
# [CV] END .....................max_depth=40, n_estimators=400; total time=   0.7s
# [CV] END .....................max_depth=40, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=40, n_estimators=400; total time=   0.7s
# [CV] END .....................max_depth=40, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=40, n_estimators=500; total time=   0.9s
# [CV] END .....................max_depth=40, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=40, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=40, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=40, n_estimators=600; total time=   1.2s
# [CV] END .....................max_depth=40, n_estimators=600; total time=   1.2s
# [CV] END .....................max_depth=40, n_estimators=600; total time=   1.2s
# [CV] END .....................max_depth=40, n_estimators=600; total time=   1.4s
# [CV] END .....................max_depth=40, n_estimators=600; total time=   1.1s
# [CV] END .....................max_depth=40, n_estimators=700; total time=   1.2s
# [CV] END .....................max_depth=40, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=40, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=40, n_estimators=700; total time=   1.2s
# [CV] END .....................max_depth=40, n_estimators=700; total time=   1.4s
# [CV] END .....................max_depth=40, n_estimators=800; total time=   1.6s
# [CV] END .....................max_depth=40, n_estimators=800; total time=   1.6s
# [CV] END .....................max_depth=40, n_estimators=800; total time=   1.5s
# [CV] END .....................max_depth=40, n_estimators=800; total time=   1.6s
# [CV] END .....................max_depth=40, n_estimators=800; total time=   1.6s
# [CV] END .....................max_depth=50, n_estimators=400; total time=   0.9s
# [CV] END .....................max_depth=50, n_estimators=400; total time=   1.0s
# [CV] END .....................max_depth=50, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=50, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=50, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=50, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=50, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=50, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=50, n_estimators=500; total time=   1.1s
# [CV] END .....................max_depth=50, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=50, n_estimators=600; total time=   1.2s
# [CV] END .....................max_depth=50, n_estimators=600; total time=   1.3s
# [CV] END .....................max_depth=50, n_estimators=600; total time=   1.2s
# [CV] END .....................max_depth=50, n_estimators=600; total time=   1.3s
# [CV] END .....................max_depth=50, n_estimators=600; total time=   1.2s
# [CV] END .....................max_depth=50, n_estimators=700; total time=   1.7s
# [CV] END .....................max_depth=50, n_estimators=700; total time=   1.4s
# [CV] END .....................max_depth=50, n_estimators=700; total time=   1.5s
# [CV] END .....................max_depth=50, n_estimators=700; total time=   1.4s
# [CV] END .....................max_depth=50, n_estimators=700; total time=   1.4s
# [CV] END .....................max_depth=50, n_estimators=800; total time=   1.6s
# [CV] END .....................max_depth=50, n_estimators=800; total time=   1.7s
# [CV] END .....................max_depth=50, n_estimators=800; total time=   1.7s
# [CV] END .....................max_depth=50, n_estimators=800; total time=   1.6s
# [CV] END .....................max_depth=50, n_estimators=800; total time=   1.6s
# [CV] END .....................max_depth=60, n_estimators=400; total time=   1.0s
# [CV] END .....................max_depth=60, n_estimators=400; total time=   0.9s
# [CV] END .....................max_depth=60, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=60, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=60, n_estimators=400; total time=   0.8s
# [CV] END .....................max_depth=60, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=60, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=60, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=60, n_estimators=500; total time=   1.1s
# [CV] END .....................max_depth=60, n_estimators=500; total time=   1.0s
# [CV] END .....................max_depth=60, n_estimators=600; total time=   1.3s
# [CV] END .....................max_depth=60, n_estimators=600; total time=   1.2s
# [CV] END .....................max_depth=60, n_estimators=600; total time=   1.3s
# [CV] END .....................max_depth=60, n_estimators=600; total time=   1.3s
# [CV] END .....................max_depth=60, n_estimators=600; total time=   1.2s
# [CV] END .....................max_depth=60, n_estimators=700; total time=   1.6s
# [CV] END .....................max_depth=60, n_estimators=700; total time=   1.6s
# [CV] END .....................max_depth=60, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=60, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=60, n_estimators=700; total time=   1.3s
# [CV] END .....................max_depth=60, n_estimators=800; total time=   1.5s
# [CV] END .....................max_depth=60, n_estimators=800; total time=   1.5s
# [CV] END .....................max_depth=60, n_estimators=800; total time=   1.5s
# [CV] END .....................max_depth=60, n_estimators=800; total time=   1.5s
# [CV] END .....................max_depth=60, n_estimators=800; total time=   1.7s
# Best parameters:  {'max_depth': 20, 'n_estimators': 600}
# Best score:  0.9665514460191267

# %%
cv_results = grid_search.cv_results_

for mean_score, params in zip(cv_results['mean_test_score'], cv_results['params']):
    print(params, mean_score)
# Out:
# {'max_depth': 10, 'n_estimators': 400} 0.9582065906210394
# {'max_depth': 10, 'n_estimators': 500} 0.9574490148634636
# {'max_depth': 10, 'n_estimators': 600} 0.9597275031685678
# {'max_depth': 10, 'n_estimators': 700} 0.9589670468948036
# {'max_depth': 10, 'n_estimators': 800} 0.9597275031685678
# {'max_depth': 20, 'n_estimators': 400} 0.9657909897453625
# {'max_depth': 20, 'n_estimators': 500} 0.9657909897453625
# {'max_depth': 20, 'n_estimators': 600} 0.9665514460191267
# {'max_depth': 20, 'n_estimators': 700} 0.9665514460191267
# {'max_depth': 20, 'n_estimators': 800} 0.9665514460191267
# {'max_depth': 30, 'n_estimators': 400} 0.9642758382302109
# {'max_depth': 30, 'n_estimators': 500} 0.9657909897453625
# {'max_depth': 30, 'n_estimators': 600} 0.9665514460191267
# {'max_depth': 30, 'n_estimators': 700} 0.9665514460191267
# {'max_depth': 30, 'n_estimators': 800} 0.9665514460191267
# {'max_depth': 40, 'n_estimators': 400} 0.9642758382302109
# {'max_depth': 40, 'n_estimators': 500} 0.9657909897453625
# {'max_depth': 40, 'n_estimators': 600} 0.9665514460191267
# {'max_depth': 40, 'n_estimators': 700} 0.9665514460191267
# {'max_depth': 40, 'n_estimators': 800} 0.9665514460191267
# {'max_depth': 50, 'n_estimators': 400} 0.9642758382302109
# {'max_depth': 50, 'n_estimators': 500} 0.9657909897453625
# {'max_depth': 50, 'n_estimators': 600} 0.9665514460191267
# {'max_depth': 50, 'n_estimators': 700} 0.9665514460191267
# {'max_depth': 50, 'n_estimators': 800} 0.9665514460191267
# {'max_depth': 60, 'n_estimators': 400} 0.9642758382302109
# {'max_depth': 60, 'n_estimators': 500} 0.9657909897453625
# {'max_depth': 60, 'n_estimators': 600} 0.9665514460191267
# {'max_depth': 60, 'n_estimators': 700} 0.9665514460191267
# {'max_depth': 60, 'n_estimators': 800} 0.9665514460191267

# %%
np.sum(grid_search.best_estimator_.predict(X_val) == Y_val) / Y_val.shape[0]
# Out:
# 0.9591836734693877

# %%
np.sum(grid_search.best_estimator_.predict(X_test) == Y_test) / Y_test.shape[0]
# Out:
# 0.9186991869918699
