# %% [markdown]
# # بسم الله الرحمن الرحيم

# %%
from utils import *
import pandas as pd 
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Reading the Dataset, cleaning , preparing it for the training

# %%
df = pd.read_csv("dataset/body_level_classification_train.csv")

# %%
df_original= cleaning_data(df).copy()

# %%
all_class_train,all_class_test=data_spliting(df_original,1/3)

# %%
oversampled= over_sampling(all_class_train,sampling_ratio=0.5)

# %%
X_train=oversampled.drop(["Body_Level"],axis=1).to_numpy()
Y_train=oversampled["Body_Level"].to_numpy()
X_test =all_class_test.drop(["Body_Level"],axis=1).to_numpy()
Y_test =all_class_test["Body_Level"].to_numpy()

# %%
X_train, scaler= data_scaling(X_train)

# %%
X_val, X_test, Y_val, Y_test = train_test_split(X_test
                                                     , Y_test, test_size=0.5, random_state=42)

# %%
X_val = scaler.transform(X_val)
X_test=scaler.transform(X_test)

# %%
model=build_model(1,0.01)

# %%
history = model.fit(X_train,Y_train,validation_data=[X_val,Y_val] 
             ,batch_size=32, epochs=500 , verbose =1, 
                       callbacks=[CustomCallback("NNModels/before_sampling/first_model.h5")])
# Out:
# Epoch 1/500
# 42/42 [==============================] - 2s 7ms/step - loss: 1.0249 - accuracy: 0.4305 - val_loss: 0.6336 - val_accuracy: 0.5796
# Epoch 2/500
# 42/42 [==============================] - 0s 3ms/step - loss: 0.5840 - accuracy: 0.6059 - val_loss: 0.4943 - val_accuracy: 0.6571
# Epoch 3/500
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4846 - accuracy: 0.6636 - val_loss: 0.4419 - val_accuracy: 0.7143
# Epoch 4/500
# 34/42 [=======================>......] - ETA: 0s - loss: 0.4374 - accuracy: 0.7188
# Yes You are here 0.7243735790252686 0.718367338180542
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4299 - accuracy: 0.7244 - val_loss: 0.4065 - val_accuracy: 0.7184
# Epoch 5/500
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3960 - accuracy: 0.7661 - val_loss: 0.3806 - val_accuracy: 0.7837
# Epoch 6/500
# ...

# %%
accurate_train_accuracy,classify_report= test_model("NNModels/before_sampling/first_model.h5",X_train,Y_train)
# Out:
# 42/42 [==============================] - 0s 873us/step

# %%
accurate_train_accuracy
# Out:
# 0.9946848899012908

# %%
print(classify_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       257
#            1       0.99      0.98      0.99       262
#            2       1.00      0.99      1.00       344
#            3       1.00      1.00      1.00       454
#
#     accuracy                           0.99      1317
#    macro avg       0.99      0.99      0.99      1317
# weighted avg       0.99      0.99      0.99      1317

# %%
accurate_val_accuracy,classify_report= test_model("NNModels/before_sampling/first_model.h5",X_val,Y_val)
# Out:
# 8/8 [==============================] - 0s 938us/step

# %%
accurate_val_accuracy
# Out:
# 0.9836734693877551

# %%
print(classify_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      0.97      0.98        31
#            2       0.96      0.99      0.97        73
#            3       0.99      0.98      0.99       112
#
#     accuracy                           0.98       245
#    macro avg       0.99      0.98      0.99       245
# weighted avg       0.98      0.98      0.98       245

# %%
accurate_test_accuracy,classify_report= test_model("NNModels/before_sampling/first_model.h5",X_test,Y_test)
# Out:
# 8/8 [==============================] - 0s 1ms/step

# %%
accurate_test_accuracy
# Out:
# 0.983739837398374

# %%
print(classify_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96        34
#            1       0.95      0.97      0.96        36
#            2       0.98      1.00      0.99        62
#            3       1.00      0.99      1.00       114
#
#     accuracy                           0.98       246
#    macro avg       0.97      0.98      0.98       246
# weighted avg       0.98      0.98      0.98       246
